# %%
import os, random, sys, time, shutil, re, csv, datetime, pickle, math 

import pandas as pd

from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.webdriver import Options

from bs4 import BeautifulSoup

# %%
chrome_options = Options()
#chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument("--log-level=3")  # fatal
chrome_options.add_argument("--start-maximized")

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

browser = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)

#browser = webdriver.Chrome("chromedriver.exe", options=chrome_options)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [C:\Users\m.dias\.wdm\drivers\chromedriver\win32\88.0.4324.96\chromedriver.exe] found in cache

# %%
browser.get("https://clutch.co/it-services/outsourcing")

# %%
# image = browser.find_element_by_class_name('company_logotype') #class="company_logotype"
# image.click()
soup = BeautifulSoup(browser.page_source, features='html.parser')
url_list = soup.find_all("div",attrs={"class" : "company_logotype"}, recursive=True)

url_list
# Out:
# [<div class="company_logotype">
#  <a href="/profile/unosquare" target="_blank">
#  <img property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/f7aaff28d20283ec98688339c07b5ecf.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/symphony-solutions" target="_blank">
#  <img property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/symphony_solutions_logo.jpg"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/intellias" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/logo-black_8.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/logo-black_8.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/dataart" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/dataart_logo.jpg" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/dataart_logo.jpg"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/sciencesoft" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/sciencesoft_logo-01.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/sciencesoft_logo-01.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/future-processing" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/0-1_7.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/0-1_7.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/eleks" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/eleks_avatar_blue_0.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/eleks_avatar_blue_0.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/itransition" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/c5fc47becc592bd9c8dfd544cbef39c7.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/c5fc47becc592bd9c8dfd544cbef39c7.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/bairesdev" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/f7f741ef174046e9e22b0a5bdff5c826.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/f7f741ef174046e9e22b0a5bdff5c826.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/empist" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/e7b07583dd381157f6644bbd8d55e53b_1.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/e7b07583dd381157f6644bbd8d55e53b_1.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/accedia" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/accedia.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/accedia.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/qburst" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/qburst_logo.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/qburst_logo.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/computer-solutions-east" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/computer_solutions_east_logo.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/computer_solutions_east_logo.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/sphere-partners" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/d7aada4dbd2ffcce49fbe451caadcaac.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/d7aada4dbd2ffcce49fbe451caadcaac.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/hyperlink-infosystem" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/logo_new.jpg" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/logo_new.jpg"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/door3" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/door3_200x200.jpg" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/door3_200x200.jpg"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/hatchworks-technologies" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/hw_logo.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/hw_logo.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/psl-corp" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/logo_1154.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/logo_1154.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/clickit-smart-technologies" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/clickit_escudo_oscuro.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/clickit_escudo_oscuro.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/sysbee" target="_blank">
#  <img class="" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/apple-touch-icon.png" loading="lazy" property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/apple-touch-icon.png"/>
#  </a>
#  </div>]

# %%
for url in url_list:
    #print(url.find('a')['href'])
    browser.get(f"https://clutch.co{url.find('a')['href']}")
    time.sleep(3)
    soup = BeautifulSoup(browser.page_source, features='html.parser')

    nome = soup.find("h1", attrs={"class" : "header-company--title"})
    nome = nome.text.replace('\n', '').strip()

    nota = soup.find("span", attrs={"itemprop" : "ratingValue"})
    nota = nota.text.replace('\n', '').strip()

    local = soup.find("span", attrs={"class" : "location-name"})
    local = local.text.replace('\n', '').strip()
    
    clients = ''
    try:
        clients = soup.find("div", attrs={"class" : "field-name-clients"})
        clients =  ' '.join([p.text.replace('\n', ' ').strip() for p in clients.find_all('p')])
    except:
        try:
            clients = soup.find("div", attrs={"class" : "field c"})
            clients = ' '.join([p.text.replace('\n', ' ').strip() for p in clients.find_all('p')])
            #clients = clients.find('p').text.replace('\n', ' ').strip()
        except:
            print(f"CLIENTES NÃO ENCONTRADOS EM {nome}")
    print(f"nome: {nome}")
    print(f"nota: {nota}")
    print(f"local: {local}")
    print(f"clientes: {clients}")
# Out:
# nome: Dev Technosys
# nota: 4.8
# local: Commerce, CA
# clientes: Nike | J &J | Hertz | Whirlpool | McKesson |Pfizer | 3M and several growing startups.
# nome: Sigma Software
# nota: 4.7
# local: Kyiv, Ukraine
# clientes:  Over the past 18 years we collaborated with Fortune 500 companies, smaller businesses, and start-ups in Western Europe and the US. Among our Key Customers are Volvo, Scania, KnorrBremse, AstraZeneca, Scandinavian Airlines, Oath, Fortum, Wargaming, LeoVegas, IGT, Mindvalley, Viaplay, DanAds, Clean.io, Mikz, Telematics Wireless, and others.
# nome: Metal Toad
# nota: 4.4
# local: Beverly Hills, CA
# clientes: ABC Television DC Comics Disney Golden Globes Intel Sony Wheel of Fortune
# nome: Belitsoft
# nota: 4.9
# local: Minsk, Belarus
# clientes:  ElearningForce, Insly, IDT Corporation, CRIMSON, NEDAP, Berkeley University, Aalborg University, Ticken.nl.
# nome: Ragnarson
# nota: 4.8
# local: Lodz, Poland
# clientes: Zurich University of the Arts, HeyJobs.co, GrowthMentor, Vehiculum.de, Verivox.de, BookingSync, GetSafe, a-connect, Memorado, Melod.ie, Kleany.de, 1FORhunger, Stewardly.ca, Docflix.tv, Glazziq.com, Certace.com, WhatToMine, Shelly Cloud.
# nome: Sciant
# nota: 4.9
# local: Sofia, Bulgaria
# clientes:  CENDYN DHL RateGain DHISCO TORA OTA Insight Protel iVvy Invata
# nome: NeenOpal Inc.
# nota: 4.9
# local: New York, NY
# clientes: 1. Unilever 2. Corel 3. The Healthy Mummy 4. McAffeine 5. Singer Retail
# nome: QArea
# nota: 4.8
# local: Kharkov, Ukraine
# clientes: Huff Post, Dashlane, Allwomenstalk, SkyHook, Distractify, Avaaz, Beakun, RebelMouse, Perx
# nome: Cynoteck Technology Solutions Pvt. Ltd.
# nota: 5.0
# local: Dehradun, India
# clientes:  Alta Environmental, Blood Hound, JLL, Microsoft
# nome: Impiger Technologies
# nota: 4.7
# local: Richardson, TX
# clientes: PwC, Beckman Coulter, Grundfos, AIDS Healthcare, Chalk Mountain, Freshbenies, Bank of Stockton, CellGate, Acero Crowns, Cherry Coatings, WatchGuard, Blais & Associates, S'moresUp, Fanpage, WASP, QTrak. We serve Startups to SMBs to Fortune 500 enterprises across industries such as Manufacturing, Logistics, Healthcare, Banking, and Financial Services. How's it to work with us? Let's hear it from our clients: https://youtu.be/JIat5lisvA4
# nome: OpsWorks Co.
# nota: 5.0
# local: Kyiv, Ukraine
# clientes:  Content Analytics, AlgoTrader, Podcast Host, Susoft.
# nome: Uplers
# nota: 4.8
# local: Sydney, Australia
# clientes:  Amazon, Facebook, National Geographic, Disney, Oracle, 21st Century Fox, DHL, Airtasker, Weight Watchers, Rover, Fortinet, Nestle, etc.
# nome: Coherent Solutions
# nota: 4.6
# local: Minneapolis, MN
# clientes:  LifeTime Fitness, Daikin, WEX Health, MTS Systems, LiquidSpace, Wildflower Health, Cargill, Starkey, Anytime Fitness.
# nome: Espeo Software
# nota: 4.7
# local: Poznań, Poland
# clientes:  Our clients include BioMensio, Ensto Oy, The Guardian Soulmates, Solita, Sanoma, Ottoboni, MeBeGood, StoreMe, and Suomen Suoramainonta. Our blockchain, projects include CloseCross, Gabrotech, MakerDao, and GHP.
# nome: HashCash Consultants
# nota: 5.0
# local: Palo Alto, CA
# clientes:  Corporates, Domestic Payment Networks, Fintech companies and Currency exchanges use the HC Network for Retail Remittances, Trade Finance, Payment Processing. Portfolio includes HC Remit, HC Corporate Payments, HC Commerce and HC Market Maker. Presence in 26 countries, HashCash has 100+ enterprises using its products. For more informations please visit https://www.hashcashconsultants.com/hashcash-network
# nome: Exoft
# nota: 4.8
# local: L'viv, Ukraine
# clientes:  LogiPlan (http://www.logiplan.se/) Safe (https://safeapp.me/) Bridgestone (https://www.bridgestone.com/)
# CLIENTES NÃO ENCONTRADOS EM CHI Software
# nome: CHI Software
# nota: 5.0
# local: Kharkiv, Ukraine
# clientes: None
# nome: Pattern Match
# nota: 4.9
# local: Gliwice, Poland
# clientes:  HRS.de, PodGroup, Kobil Systems GmbH, DTiQ, Informed Solutions Ltd
# nome: Folio3
# nota: 4.9
# local: Belmont, CA
# clientes: American Angus Association  SquareTrade Inc  Barnes & Noble  Alibaba Group  Cisco  Sony  Mercedes Benz  Honda UK  Jaguar LandRover  Air Medical Group Holdings Inc.  Kravis Kholberg Roberts (KKR) & Co.  Hiplink  Zoetis  Merck  Colgate Palmolive  SAP  Savills UK  Standard Chartered   Agri Beef Co
# nome: Rubyroid Labs
# nota: 5.0
# local: Minsk, Belarus
# clientes: Big Purple Dot - real estate CRM system, USA.  Volition Beauty - kickstarter-like beauty platform, USA.  Volvo - a mobile app for car washing, UK.  Rocketwash - automation system for car wash business, Russia.   Sail Croatia - a travel CRM system, UK. Letknow - trading & exchange platforms, Estonia.  Digital marketing agency, USA. Architecture and interior design software company, USA.

# %%
for i in range(4):
    browser.get(f"https://clutch.co/it-services/outsourcing?page={i}")
    soup = BeautifulSoup(browser.page_source, features='html.parser')
    url_list = soup.find_all("div",attrs={"class" : "company_logotype"}, recursive=True)
    for url in url_list:
        print(url.find('a')['href'])
# Out:
# /profile/unosquare
# /profile/symphony-solutions
# /profile/intellias
# /profile/dataart
# /profile/sciencesoft
# /profile/future-processing
# /profile/eleks
# /profile/itransition
# /profile/bairesdev
# /profile/empist
# /profile/accedia
# /profile/qburst
# /profile/computer-solutions-east
# /profile/sphere-partners
# /profile/hyperlink-infosystem
# /profile/door3
# /profile/hatchworks-technologies
# /profile/psl-corp
# /profile/clickit-smart-technologies
# /profile/sysbee
# /profile/n-ix
# /profile/opinov8-technology-services
# /profile/avenga
# /profile/ibexlabs
# /profile/delaplex
# /profile/velotio-technologies
# /profile/binariks
# /profile/chimera-prime
# /profile/unicsoft
# /profile/techmagic
# /profile/mutual-mobile
# /profile/forte-group
# /profile/icreon
# /profile/skelia
# /profile/gorilla-logic
# /profile/diceus
# /profile/ide3
# /profile/synebo
# /profile/experion-technologies
# /profile/alpacked
# /profile/algoworks
# /profile/superadmins
# /profile/ishir
# /profile/sombra
# /profile/devcom
# /profile/code-runners
# /profile/inflection-point
# /profile/inmediatum
# /profile/brimit
# /profile/amplework-software
# /profile/jetruby-agency
# /profile/webbylab
# /profile/prismetric
# /profile/britenet
# /profile/tudip-technologies
# /profile/alliancetek
# /profile/successive-technologies
# /profile/softwarehut
# /profile/nbc-it-outsourcing
# /profile/imaginary-cloud
# /profile/dev-technosys
# /profile/sigma-software
# /profile/metal-toad
# /profile/belitsoft
# /profile/ragnarson
# /profile/sciant
# /profile/neenopal
# /profile/qarea
# /profile/cynoteck-technology-solutions
# /profile/impiger-technologies
# /profile/opsworks-co
# /profile/uplers
# /profile/coherent-solutions
# /profile/espeo-software
# /profile/hashcash-consultants
# /profile/exoft
# /profile/chi-software
# /profile/pattern-match
# /profile/folio3
# /profile/rubyroid-labs

# %%
# nome -- h1 class header-company--title 
# nota -- span itemprop ratingValue
# local -- span class location-name
# clients -- div class field-name-clients // field c -> p
browser.get("https://clutch.co/profile/pattern-match")

# %%
soup = BeautifulSoup(browser.page_source, features='html.parser')

nome = soup.find("h1", attrs={"class" : "header-company--title"})
nome = nome.text.replace('\n', '').strip()

nota = soup.find("span", attrs={"itemprop" : "ratingValue"})
nota = nota.text.replace('\n', '').strip()

local = soup.find("span", attrs={"class" : "location-name"})
local = local.text.replace('\n', '').strip()

try:
    clients = soup.find("div", attrs={"class" : "field-name-clients"})
    clients = ' '.join([p.text for p in clients.find_all('p')])
except:
    try:
        clients = soup.find("div", attrs={"class" : "field c"})
        clients = ' '.join([p.text for p in clients.find_all('p')])
    except:
        print(nome)

print(f"nome: {nome}")
print(f"nota: {nota}")
print(f"local: {local}")
print(f"clientes: {clients}")
# Out:
# nome: Pattern Match
# nota: 4.9
# local: Gliwice, Poland
# clientes:  HRS.de, PodGroup, Kobil Systems GmbH, DTiQ, Informed Solutions Ltd
