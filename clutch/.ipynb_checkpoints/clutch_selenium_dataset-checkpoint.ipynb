# %%
import os, random, sys, time, shutil, re, csv, datetime, pickle, math 

import pandas as pd

from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.webdriver import Options

from bs4 import BeautifulSoup

# %%
chrome_options = Options()
#chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument("--log-level=3")  # fatal
chrome_options.add_argument("--start-maximized")

# %%
#!pip install webdriver_manager --user

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

browser = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)

#browser = webdriver.Chrome("chromedriver.exe", options=chrome_options)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [C:\Users\guilherme.soriano\.wdm\drivers\chromedriver\win32\88.0.4324.96\chromedriver.exe] found in cache

# %%
browser.get("https://clutch.co/it-services/outsourcing")

# %%
# image = browser.find_element_by_class_name('company_logotype') #class="company_logotype"
# image.click()
soup = BeautifulSoup(browser.page_source, features='html.parser')
url_list = soup.find_all("div",attrs={"class" : "company_logotype"}, recursive=True)

url_list
# Out:
# [<div class="company_logotype">
#  <a href="/profile/unosquare" target="_blank">
#  <img property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/f7aaff28d20283ec98688339c07b5ecf.png"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/symphony-solutions" target="_blank">
#  <img property="image" src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/symphony_solutions_logo.jpg"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/intellias" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/logo-black_8.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/dataart" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/dataart_logo.jpg" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/sciencesoft" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/sciencesoft_logo-01.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/future-processing" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/0-1_7.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/eleks" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/eleks_avatar_blue_0.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/itransition" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/c5fc47becc592bd9c8dfd544cbef39c7.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/bairesdev" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/f7f741ef174046e9e22b0a5bdff5c826.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/empist" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/e7b07583dd381157f6644bbd8d55e53b_1.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/accedia" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/accedia.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/qburst" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/qburst_logo.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/computer-solutions-east" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/computer_solutions_east_logo.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/sphere-partners" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/d7aada4dbd2ffcce49fbe451caadcaac.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/hyperlink-infosystem" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/logo_new.jpg" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/door3" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/door3_200x200.jpg" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/hatchworks-technologies" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/hw_logo.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/psl-corp" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/logo_1154.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/clickit-smart-technologies" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/clickit_escudo_oscuro.png" loading="lazy" property="image"/>
#  </a>
#  </div>,
#  <div class="company_logotype">
#  <a href="/profile/sysbee" target="_blank">
#  <img class="lazy" data-src="https://img.shgstatic.com/clutchco-static/image/scale/65x65/s3fs-public/logos/apple-touch-icon.png" loading="lazy" property="image"/>
#  </a>
#  </div>]

# %%
# nome -- h1 class header-company--title 
# nota -- span itemprop ratingValue
# local -- span class location-name
# clients -- div class field-name-clients // field c -> p
browser.get("https://clutch.co/profile/pattern-match")

# %%
url_list_string = []
for i in range(2):
    browser.get(f"https://clutch.co/it-services/outsourcing?page={i}")
    soup = BeautifulSoup(browser.page_source, features='html.parser')
    #url_list.append(soup.find_all("div",attrs={"class" : "company_logotype"}, recursive=True))
    url_list = (soup.find_all("div",attrs={"class" : "company_logotype"}, recursive=True))
    
    for url in url_list:
           url_list_string.append(url.find('a')['href'])

# %%
url_list_string
# Out:
# ['/profile/unosquare',
#  '/profile/symphony-solutions',
#  '/profile/intellias',
#  '/profile/dataart',
#  '/profile/sciencesoft',
#  '/profile/future-processing',
#  '/profile/eleks',
#  '/profile/itransition',
#  '/profile/bairesdev',
#  '/profile/empist',
#  '/profile/accedia',
#  '/profile/qburst',
#  '/profile/computer-solutions-east',
#  '/profile/sphere-partners',
#  '/profile/hyperlink-infosystem',
#  '/profile/door3',
#  '/profile/hatchworks-technologies',
#  '/profile/psl-corp',
#  '/profile/clickit-smart-technologies',
#  '/profile/sysbee',
#  '/profile/n-ix',
#  '/profile/opinov8-technology-services',
#  '/profile/avenga',
#  '/profile/ibexlabs',
#  '/profile/techmagic',
#  '/profile/delaplex',
#  '/profile/velotio-technologies',
#  '/profile/binariks',
#  '/profile/chimera-prime',
#  '/profile/unicsoft',
#  '/profile/mutual-mobile',
#  '/profile/forte-group',
#  '/profile/icreon',
#  '/profile/devcom',
#  '/profile/skelia',
#  '/profile/gorilla-logic',
#  '/profile/diceus',
#  '/profile/ishir',
#  '/profile/ide3',
#  '/profile/synebo']

# %%
name = []
note = []
place = []
client = []

for url in url_list_string:
    #print(url.find('a')['href'])
    browser.get(f"https://clutch.co{url}")
    time.sleep(3)
    soup = BeautifulSoup(browser.page_source, features='html.parser')

    nome = soup.find("h1", attrs={"class" : "header-company--title"})
    nome = nome.text.replace('\n', '').strip()
    name.append(nome)

    nota = soup.find("span", attrs={"itemprop" : "ratingValue"})
    nota = nota.text.replace('\n', '').strip()
    note.append(nota)

    local = soup.find("span", attrs={"class" : "location-name"})
    local = local.text.replace('\n', '').strip()
    place.append(local)
    
    clients = ''
    try:
        clients = soup.find("div", attrs={"class" : "field-name-clients"})
        clients =  ' '.join([p.text.replace('\n', ' ').strip() for p in clients.find_all('p')])
        client.append(clients)
    except:
        try:
            clients = soup.find("div", attrs={"class" : "field c"})
            clients = ' '.join([p.text.replace('\n', ' ').strip() for p in clients.find_all('p')])
            #clients = clients.find('p').text.replace('\n', ' ').strip()
            client.append(clients)
        except:
            clients = ' : '.join(["Clientes não encontrados para a empresa",nome])
            clients = f"Clientes não encontrados para a empresa : {nome}"

            client.append(clients)
    #print(f"nome: {nome}")
    #print(f"nota: {nota}")
    #print(f"local: {local}")
    #print(f"clientes: {clients}")

# %%
def preenche_pais(x):
    if len(x.split(", ")[1]) == 2:
        return (x.split(", ")[1]), "United States"
    else:
        return " ", x.split(", ")[1]

# %% [markdown]
# dict = {'nome': name, 'nota': note, 'local': place, 'clients':client}
# df = pd.DataFrame(dict)
# df['cidade'] = df.local.str.split(",",expand=True,)[0]
# df['estado'], df['pais'] = zip(*df.local.apply(preenche_pais))
# df

# %%
dict = {'nome': name, 'nota': note, 'local': place, 'clients':client} 
df = pd.DataFrame(dict)
df['cidade'] = df.local.str.split(",",expand=True,)[0]
df[['estado','pais']] = pd.DataFrame(df.local.apply(preenche_pais).tolist(), index=df2.index)
df
# Out:
#                            nome nota                   local  \
# 0                Unosquare, LLC  4.9         Lake Oswego, OR
# 1            Symphony Solutions  4.8  Amsterdam, Netherlands
# 2                     Intellias  4.9           Lviv, Ukraine
# 3                       DataArt  5.0            New York, NY
# 4                   ScienceSoft  4.8            McKinney, TX
# 5             Future Processing  4.8         Gliwice, Poland
# 6                         ELEKS  4.8           Lviv, Ukraine
# 7                   Itransition  4.9              Denver, CO
# 8                     BairesDev  4.8       San Francisco, CA
# 9                        EMPIST  4.8             Chicago, IL
# 10                      Accedia  4.7         Sofia, Bulgaria
# 11                       QBurst  4.6       Trivandrum, India
# 12      Computer Solutions East  5.0        New Rochelle, NY
# 13              Sphere Partners  4.9          Northbrook, IL
# 14         Hyperlink InfoSystem  4.9        Ahmedabad, India
# 15                        DOOR3  4.9            New York, NY
# 16      HatchWorks Technologies  4.9             Atlanta, GA
# 17                    PSL Corp.  4.7      Medellín, Colombia
# 18   ClickIT Smart Technologies  4.9        Saltillo, Mexico
# 19                       Sysbee  5.0           Pula, Croatia
# 20                         N-iX  4.9           Lviv, Ukraine
# 21  Opinov8 Technology Services  4.8  London, United Kingdom
# 22                       Avenga  4.8       Rochelle Park, NJ
# 23                     Ibexlabs  5.0           Princeton, NJ
# 24                    TechMagic  4.7           Lviv, Ukraine
# 25                     delaPlex  5.0             Atlanta, GA
# 26         Velotio Technologies  4.6             Pune, India
# 27                     Binariks  5.0           Lviv, Ukraine
# 28             Chimera Prime AS  4.7            Oslo, Norway
# 29                     Unicsoft  4.9           Kiev, Ukraine
# 30                Mutual Mobile  4.8              Austin, TX
# 31                  Forte Group  4.9             Chicago, IL
# 32                       Icreon  5.0            New York, NY
# 33                       DevCom  4.9           Lviv, Ukraine
# 34                       Skelia  4.7           Lviv, Ukraine
# 35                Gorilla Logic  4.8          Broomfield, CO
# 36                       Diceus  4.8           Kyiv, Ukraine
# 37                        ISHIR  4.9               Plano, TX
# 38                         IDE3  5.0         Zagreb, Croatia
# 39                       Synebo  4.9               Dover, DE
#
#                                               clients         cidade estado  \
# 0   Clientes não encontrados para a empresa : Unos...    Lake Oswego     OR
# 1   Vivino - #1 wine app/platform in the world (Da...      Amsterdam
# 2    HERE Technologies, Siemens, Deloitte, LG Elec...           Lviv
# 3    DataArt serves clients in finance, insurance,...       New York     NY
# 4    Walmart, Heinz, Nestle, IBM, NASA JPL, T-Mobi...       McKinney     TX
# 5    Tenneco // The Linde Group // Ista // Credit ...        Gliwice
# 6    Aramex; Autodesk; ESET; TAIT; Havas; Eagle In...           Lviv
# 7    Expedia, Xerox, Toyota, eBay, PayPal, adidas,...         Denver     CO
# 8    Google, Rolls-Royce, Pinterest, EY, Urban Out...  San Francisco     CA
# 9    Businesses with 20-100 employees and an offic...        Chicago     IL
# 10  Alexander Forbes, Bulstrad Vienna Insurance Gr...          Sofia
# 11   United Nations, NYU, PrivateFly, Petrofac, Al...     Trivandrum
# 12   • Sandell Asset Management Corp, • Durst Corp...   New Rochelle     NY
# 13  Buzzfeed, Tumblr, Nokia, Subway, Land's End, S...     Northbrook     IL
# 14       Discovery, Viacom, Disney, Cartoon Network.       Ahmedabad
# 15   AIG, Everest, HP, Freedom Mortgage, Stillwell...       New York     NY
# 16  AT&T, Diebold Nixdorf, Cricket Wireless, Chart...        Atlanta     GA
# 17   Fortune 500/Large: IPG, Deloitte, Flex, MuleS...       Medellín
# 18   Ticketbooth Boatsetter Trumedia Blade IBSS Cu...       Saltillo
# 19   Clientes não encontrados para a empresa : Sysbee           Pula
# 20   Fortune 500 companies, Gogo, Fluke, TuneIn, H...           Lviv
# 21   Fortune 500 Companies, Computer and IT servic...         London
# 22   Clientes não encontrados para a empresa : Avenga  Rochelle Park     NJ
# 23   Swellbottle, HealthBridge Financial, Skubana,...      Princeton     NJ
# 24  Clientes não encontrados para a empresa : Tech...           Lviv
# 25  Clientes não encontrados para a empresa : dela...        Atlanta     GA
# 26  Clientes não encontrados para a empresa : Velo...           Pune
# 27  eMotorWercks (Enel Group Company), OneTouch, O...           Lviv
# 28  Since 2012 we've developed digital products fo...           Oslo
# 29   Hoodifood, Executive Eye, Goforit, Security D...           Kiev
# 30   We’ve helped many of the world’s leading bran...         Austin     TX
# 31   BMO Harris Bank, Serta Simmons Bedding, CNH I...        Chicago     IL
# 32   IMG Models, National Geographic Channel, FOX ...       New York     NY
# 33   DevCom provides complex and cost-effective ye...           Lviv
# 34   Clientes não encontrados para a empresa : Skelia           Lviv
# 35   A Place for Mom, Arrow Electronics, DaVita, M...     Broomfield     CO
# 36  Willis Towers Watson, Bridgestone, Bank al Eti...           Kyiv
# 37   Automobile (Honda) Digital Marketing (SQ1, Ow...          Plano     TX
# 38   Kaufland, Horwath HTL, Crowe, Amaris Consulti...         Zagreb
# 39   GreenRoad, Audyx, Deloitte, IBM, SIRIN LABS, ...          Dover     DE
#
#               pais
# 0    United States
# 1      Netherlands
# 2          Ukraine
# 3    United States
# 4    United States
# 5           Poland
# 6          Ukraine
# 7    United States
# 8    United States
# 9    United States
# 10        Bulgaria
# 11           India
# 12   United States
# 13   United States
# 14           India
# 15   United States
# 16   United States
# 17        Colombia
# 18          Mexico
# 19         Croatia
# 20         Ukraine
# 21  United Kingdom
# 22   United States
# 23   United States
# 24         Ukraine
# 25   United States
# 26           India
# 27         Ukraine
# 28          Norway
# 29         Ukraine
# 30   United States
# 31   United States
# 32   United States
# 33         Ukraine
# 34         Ukraine
# 35   United States
# 36         Ukraine
# 37   United States
# 38         Croatia
# 39   United States

# %% [markdown]
# soup = BeautifulSoup(browser.page_source, features='html.parser')
#
# nome = soup.find("h1", attrs={"class" : "header-company--title"})
# nome = nome.text.replace('\n', '').strip()
#
# nota = soup.find("span", attrs={"itemprop" : "ratingValue"})
# nota = nota.text.replace('\n', '').strip()
#
# local = soup.find("span", attrs={"class" : "location-name"})
# local = local.text.replace('\n', '').strip()
#
# try:
#     clients = soup.find("div", attrs={"class" : "field-name-clients"})
#     clients = ' '.join([p.text for p in clients.find_all('p')])
# except:
#     try:
#         clients = soup.find("div", attrs={"class" : "field c"})
#         clients = ' '.join([p.text for p in clients.find_all('p')])
#     except:
#         print(nome)
#
# print(f"nome: {nome}")
# print(f"nota: {nota}")
# print(f"local: {local}")
# print(f"clientes: {clients}")
